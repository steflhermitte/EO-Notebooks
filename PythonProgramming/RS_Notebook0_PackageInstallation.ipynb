# %% [markdown]
# <a href="https://colab.research.google.com/github/steflhermitte/EO-Notebooks/blob/master/PythonProgramming/RS_Notebook0_PackageInstallation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Package installation
# During the Bouwplaats CTB2000-D4a you will use several geospatial and remote sensing analysis python packages that you will need to install and which are listed below. You can do that on your [local computer conda distribution](https://colab.research.google.com/drive/1MccJkybH3jEDeQ8GkU7NmtbXP8ZE4V5M#scrollTo=5xZFlmwfWgaT&line=3&uniqifier=1) or using the cloud-based [Google Colab](https://colab.research.google.com/drive/1MccJkybH3jEDeQ8GkU7NmtbXP8ZE4V5M#scrollTo=QqIqquqdXvaG&line=1&uniqifier=1) online jupyter notebooks. For both setups short manual on how to install the necessary packages is included, where the local setup is probably the most convenient for data handling, whereas the colab setup should give you a good backup in case you have a techical installation problem.

# %% [markdown]
# ## Required packages
# We will use three packages that you need to install separately in your jupyter/conda environment:
# * <a href="https://scitools.org.uk/cartopy/docs/latest/" target="_blank">Cartopy</a>: a Python package designed for geospatial data processing in order to produce maps and other geospatial data analyses.
# * <a href="" target="_blank">Matplotlib-scalbar</a>: a Python package designed for adding scalebars to figures and maps.
# * <a href="https://osmnx.readthedocs.io/en/stable/#" target="_blank">OSMnx</a> : a Python package designed to download spatial geometries and model, project, visualize, and analyze street networks and other spatial data from OpenStreetMap’s APIs.
# * <a href="https://scikit-learn.org/stable/" target="_blank">scikit-learn</a> a Python package designed to machine learning in python
# * <a href="https://geemap.org/" target="_blank">geemap</a> a Python package for for interactive mapping with Google Earth Engine
# * <a href="https://geopandas.org/" target="_blank">geopandas</a> a Python package to make working with geospatial data in python easier. GeoPandas extends the datatypes used by pandas to allow spatial operations on geometric types.
# * <a href="https://rasterio.readthedocs.io/en/latest/index.html" target="_blank">rasterio</a> a Python package to process different kind of geospatial raster data files. Rasterio reads and writes these formats and provides a Python API based on Numpy N-dimensional arrays and GeoJSON.
# * <a href="https://geopython.github.io/OWSLib/" target="_blank">owslib</a> a Python package for client programming with Open Geospatial Consortium (OGC) web service (hence OWS) interface standards, and their related content models.
# * <a href="https://pyepsg.readthedocs.io/en/latest/" target="_blank">pyepsg</a> a Python package for reading/writing epsg.io coordinates reference systems

# %% [markdown]
# # Local installation in your own python environment
#
# To install the packages on your local computer
# The easiest route to installing osmnx & cartopy is through conda by running the following 4 commands in your conda prompt.
#
# * For windows you should first launch your conda prompt. If you don't know how to launch the conda prompt in Windows check [here](https://docs.anaconda.com/anaconda/install/verify-install/#conda). Once the conda prompt is launched, you should run the following four commands in this prompt:
#
# * For Mac you should open your terminal (Spotlight Search -> Terminal) and the you can directly run the following commands in the terminal:
#
# `conda create -n BPD4a -c conda-forge python=3`
#
# This line is to create a new conda environment with name BPD4a (i.e. BouwPlaats D4a). Subsequently, you need to active that newly created environment:
#
# `conda activate BPD4a`
#
# Within this environment, you can first install `mamba` to facilitate faster package installation ([check for more info](https://github.com/mamba-org/mamba))
#
# `conda install -c conda-forge mamba`
#
# Once in the newly created environment you can install the necessary packages:
#
# `mamba install osmnx cartopy matplotlib-scalebar pyepsg scikit-learn geemap geopandas rasterio owslib glob2 imageio`
#
# If this does not work you can test:
#
# `mamba install -c conda-forge osmnx cartopy matplotlib-scalebar pyepsg scikit-learn geemap geopandas rasterio owslib  glob2 imageio`
#
# Once you succeeded in installing these packages, you have to switch to BPD4a environment (see screenshot).
#
# Once this is done, these packages can be imported as normal packages as you have done in previous CTB2000 notebooks and you should be able to run the code at the end of this notebook without major errors. If this is the case you are fine to start the Bouwplaats sessions.

# %% [markdown]
# # Installation on Google colab
#
# To run the notebook in the cloud, you need to install the packages in your Colab online environment. First, you start by authenticating Colab to interact with your google drive for loading/saving data from/to your drive. For this you need to run the following package and authorize Colab by copying the authentication token.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Subsequently, you install `osmnx`

# %%
# !apt install libspatialindex-dev
# !pip install osmnx
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libspatialindex-c4v5 libspatialindex4v5
# The following NEW packages will be installed:
#   libspatialindex-c4v5 libspatialindex-dev libspatialindex4v5
# 0 upgraded, 3 newly installed, 0 to remove and 39 not upgraded.
# Need to get 555 kB of archives.
# After this operation, 3,308 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex4v5 amd64 1.8.5-5 [219 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex-c4v5 amd64 1.8.5-5 [51.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex-dev amd64 1.8.5-5 [285 kB]
# Fetched 555 kB in 1s (689 kB/s)
# Selecting previously unselected package libspatialindex4v5:amd64.
# (Reading database ... 155455 files and directories currently installed.)
# ...

# %% [markdown]
# You will see that it will ask to `restart runtime` which you should do before proceeding. Subsequently, you can install the other necessary packages.

# %%
# !apt-get install libproj-dev proj-data proj-bin
# !apt-get install libgeos-dev
# !pip install cython
# !pip install git+https://github.com/SciTools/cartopy.git --no-binary cartopy
# !apt-get -qq install python-cartopy python3-cartopy
# !pip install cartopy geemap
# !pip uninstall -y shapely    # cartopy and shapely aren't friends 
# !pip install shapely --no-binary shapely

# %%
# !pip install matplotlib-scalebar
# !pip install pyepsg
# !pip install owslib
# !pip install scikit-learn
# !pip install geopandas
# !pip install rasterio
# !pip install geemap
# Out:
# ...
#      |████████████████████████████████| 216 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 19.3 MB 1.1 MB/s
# ...

# %% [markdown]
# If the code asks to restart runtime which you should do so before proceeding.

# %% [markdown]
# # Test installed packages
#
# Below you can find some test code that you should be able to run without errors. Only some download warnings may occur, but that is normal. For the functionality of the code, we will learn how to use etc in more detail during the notebook classes, so don't worry if you don't understand the code yet.

# %% [markdown]
# ## For notebook 1

# %%
import cartopy.crs as ccrs
import cartopy
import geopandas
import osmnx as ox
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar
import numpy as np
import cartopy.feature as cfeature
# %matplotlib inline

# %%
ccrs.epsg(32631)
# Out:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:228: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:347: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})
ax.coastlines()

# %%
import numpy as np
central_lon, central_lat = -10, 45
extent = [-20, 20, 30, 60] # with (x0, x1, y0, y1) of the map in the given coordinate system.
ax = plt.axes(projection=ccrs.Orthographic(central_lon, central_lat),title='Europe')
ax.set_extent(extent)
ax.coastlines(resolution='50m')
ax.gridlines()
scalebar = ScaleBar(1,box_alpha=0)
ax.add_artist(scalebar)
# Out:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:228: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:347: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...

# %%
rivers_50m = cfeature.NaturalEarthFeature('physical', 'rivers_lake_centerlines', '50m')

plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.AlbersEqualArea(central_lon, central_lat))
ax.set_extent(extent)

ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND, edgecolor='black')
ax.add_feature(rivers_50m, facecolor='None', edgecolor='b')
ax.gridlines()
# Out:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:228: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:347: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...

# %%
fig = plt.figure(figsize=(8, 12))
central_lon, central_lat = -10, 45
extent = [-20, 20, 30, 60] # with (x0, x1, y0, y1) of the map in the given coordinate system.
ax = plt.axes(projection=ccrs.Orthographic(central_lon, central_lat),title='Europe')
ax.set_extent(extent)
ax.coastlines(resolution='50m')
ax.gridlines()
ax.add_wms(wms='https://gibs.earthdata.nasa.gov/wms/epsg4326/best/wms.cgi',layers=['VIIRS_SNPP_CorrectedReflectance_TrueColor'],wms_kwargs={'time':'2021-01-01'})
# Out:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:228: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:280: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /usr/local/lib/python3.7/dist-packages/cartopy/crs.py:347: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...

# %%
G = ox.graph_from_place('Delft, Netherlands')
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
nodes, edges = ox.graph_to_gdfs(G)
nodes.head()
# Out:
#                   y         x  street_count highway  ref  \
# osmid
# 25315531  52.022649  4.374519             4     NaN  NaN
# 25315533  52.021251  4.375429             4     NaN  NaN
# 25315535  52.021777  4.371906             4     NaN  NaN
# 25315544  52.023888  4.383701             3     NaN  NaN
# 25315553  52.021946  4.387287             4     NaN  NaN
#
#                           geometry
# osmid
# 25315531  POINT (4.37452 52.02265)
# 25315533  POINT (4.37543 52.02125)
# 25315535  POINT (4.37191 52.02178)
# 25315544  POINT (4.38370 52.02389)
# 25315553  POINT (4.38729 52.02195)

# %%
filename='https://raw.githubusercontent.com/steflhermitte/EO-Notebooks/master/vegetation.geojson'
import geopandas
df = geopandas.read_file(filename)

# %%
plt.figure()
crs=ccrs.PlateCarree()
ax = plt.axes(projection=crs)
ax.set_extent([4.36,4.39,51.98,52.01])
ax.add_geometries(edges['geometry'],crs=crs,linewidth=1, edgecolor='red',facecolor='None')
ax.add_geometries(df['geometry'],crs=crs,linewidth=0, edgecolor='None',facecolor='green')

# %% [markdown]
# ## For notebook 2

# %%
import geemap
import rasterio
import ee
import geemap
import os
import shutil

# %% [markdown]
# Now you need to authenticate Google Earth Engine. Therefore you first need an earth engine account for which you can register [here](https://signup.earthengine.google.com/).

# %%
## Authenticate EE
ee.Authenticate()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=R9se3iEoaq9ybeWbY2H0ALgRJVS5EGtb3_r4bXqD-Pk&tc=s5BmU5GJ-zRJ-tWOfUDj4baGxi-H5SrIN07DZ1QX6Zo&cc=oE3PgkK96ZUzwqoxGKKtuyL_86m6I_CTPf6lHl2vP3Q
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AX4XfWhITCl_3vk7USvDvnC34sGkG3S6gBnC9gm_losCteeF9ffFIsHCObg
#
# Successfully saved authorization token.

# %%
# Launch EE
ee.Initialize()

# %%
roi = ee.Geometry.Polygon([[[-115.413031, 35.889467],
[-115.413031, 36.543157],
[-114.034328, 36.543157],
[-114.034328, 35.889467],
[-115.413031, 35.889467]]])

collection = ee.ImageCollection("COPERNICUS/S2_SR") \
    .filterBounds(roi) \
    .filterDate('2019-11-01', '2019-11-5') \
    .filterMetadata('CLOUDY_PIXEL_PERCENTAGE','less_than',5) \
    .select('B4') \
    .mean().clip(roi).unmask()

# %% [markdown]
# Uncomment one of the following lines to set your output directoryt (depending if work on your local computer or colab).

# %%
# If on local computer
out_dir = os.path.join(os.path.expanduser('~'), 'Downloads')
# If on colab
out_dir = '/content/'
filename = os.path.join(out_dir, 'landsat.tif')

# %%
geemap.ee_export_image(collection, filename=filename,region=roi, scale=100, file_per_band=False)
# Out:
# Generating URL ...
# ...
# Please wait ...
# Data downloaded to /content/landsat.tif

# %%
src = rasterio.open(filename, 'r')
plt.imshow(src.read(1), cmap='pink')

# %% [markdown]
# ## For notebook 3
# No specific tests

# %% [markdown]
# # Done
# If all cells work without problems, you are ready to start the notebook sessions in the quarter. Good luck!
