# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import datetime
import numpy as np

import matplotlib.pyplot as plt

# %%
# !pip install -U sentinelhub
# Out:
# ...
#      |████████████████████████████████| 174kB 3.5MB/s
# ...
#      |████████████████████████████████| 133kB 49.7MB/s
# ...
#      |████████████████████████████████| 10.1MB 55.7MB/s
# ...
#   Created wheel for sentinelhub: filename=sentinelhub-2.6.0-cp36-none-any.whl size=174968 sha256=fcdd1b7b7273fbd149450ab248dc5c3e71ef13e9e3bc3b65dff04382613f1560
#   Stored in directory: /root/.cache/pip/wheels/6f/b5/7c/0a1a2940b130f4878a319c454efd1e1dd1b1032660196ad391
# ...
#   Created wheel for utm: filename=utm-0.5.0-cp36-none-any.whl size=5903 sha256=bda6bdea5e6bac17d703ae3ffebc99c99dee81e88e354838e85b33997d6fdddc
#   Stored in directory: /root/.cache/pip/wheels/22/85/c2/314ffed39b8e02ca623e9b7d2ad7fcf3f8544a0e77c096be76
# Successfully built sentinelhub utm
# ...

# %%
from sentinelhub import WmsRequest, WcsRequest, MimeType, CRS, BBox

# %%
def plot_image(image, factor=1):
    """
    Utility function for plotting RGB images.
    """
    fig = plt.subplots(nrows=1, ncols=1, figsize=(15, 7))

    if np.issubdtype(image.dtype, np.floating):
        plt.imshow(np.minimum(image * factor, 1))
    else:
        plt.imshow(image)

# %%
betsiboka_coords_wgs84 = [46.16, -16.15, 46.51, -15.58]
betsiboka_bbox = BBox(bbox=betsiboka_coords_wgs84, crs=CRS.WGS84)

# %%
# INSTANCE_ID = 'de259ea4-2528-6fad-f126-6f295ac9fad1'  # In case you put instance ID into cofniguration file you can leave this unchanged
INSTANCE_ID = 'b7b5e3ef-5a40-4e2a-9fd3-75ca2b81cb32'  # In case you put instance ID into cofniguration file you can leave this unchanged

# %%
wms_true_color_request = WmsRequest(layer='1_NATURAL_COL0R',
                                    bbox=betsiboka_bbox,
                                    time='2017-12-15',
                                    width=512, height=856,
                                    instance_id=INSTANCE_ID)
wms_true_color_img = wms_true_color_request.get_data()
print('Returned data is of type = %s and length %d.' % (type(wms_true_color_img), len(wms_true_color_img)))
print('Single element in the list is of type {} and has shape {}'.format(type(wms_true_color_img[-1]), wms_true_color_img[-1].shape))
plot_image(wms_true_color_img[-1])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/sentinelhub/download.py in execute_download_request(request)
#     235                 response = _do_request(request)
# --> 236                 response.raise_for_status()
#     237                 response_content = response.content
#
# /usr/local/lib/python3.6/dist-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# ...
